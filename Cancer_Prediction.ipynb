# %% [markdown]
# <a href="https://colab.research.google.com/github/HHansi/Applied-AI-Course/blob/main/Cancer_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Breast Cancer Diagnosis with NN
#
# This notebook contains practical examples and exercises for Applied AI-DL and Optimisation.
#
# *Created by Hansi Hettiarachchi*

# %% [markdown]
# This tutorial will guide you through the process of building and optimising neural network models targeting a real-world problem.

# %%
# import libraries
import pandas as pd
import seaborn as sns

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

from sklearn import metrics

# set random seeds to get reproducible results
import os
seed = 100
os.environ['PYTHONHASHSEED']=str(seed) 
keras.utils.set_random_seed(seed) # set all random seeds for the program (Python, NumPy, and TensorFlow)

# %% [markdown]
# **Random seeds**
#
# It is important to set random seeds to fixed values to generate reproducible results.
#
# If the random seeds are not fixed, the initial weights of the neural network will assign randomly, resulting in different models (in terms of weights).
#
# More details on generating reproducible results in Keras are available in the below links.
# * [How can I obtain reproducible results using Keras during development?](https://keras.io/getting_started/faq/#how-can-i-obtain-reproducible-results-using-keras-during-development)
# * [tf.keras.utils.set_random_seed](https://www.tensorflow.org/api_docs/python/tf/keras/utils/set_random_seed)

# %% [markdown]
# ## Understanding the problem and data set
#
# I use [Breast Cancer Wisconsin (Diagnostic) Data Set
# ](https://www.kaggle.com/uciml/breast-cancer-wisconsin-data) for this tutorial.
#
# Features available with this data set are computed from a digitised image of a fine needle aspirate (FNA) of a breast mass. They describe the characteristics of the cell nuclei present in the image.<br>
# The diagnosed labels are 'M' and 'B', which correspond to malignant and benign.
#
# The targeted problem is to predict the tumour type given the features computed from digitised images. Let's train a simple neural network to make this prediction.

# %% [markdown]
# ### Load and analyse the data set

# %%
# load the data set
# As the parameter, the file path should be provided. Additionally, GitHub URL can also be provided as follows.
df = pd.read_csv('https://raw.githubusercontent.com/HHansi/Applied-AI-Course/main/DL/data/cancer_data.csv')

# summarise the details
print(f'Number of entries: {len(df)}')
df.head()
# Out:
# Number of entries: 569
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0  ...         25.38          17.33           184.60      2019.0
# 1  ...         24.99          23.41           158.80      1956.0
# 2  ...         23.57          25.53           152.50      1709.0
# 3  ...         14.91          26.50            98.87       567.7
# 4  ...         22.54          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst
# 0          0.4601                  0.11890
# 1          0.2750                  0.08902
# 2          0.3613                  0.08758
# 3          0.6638                  0.17300
# 4          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
#  14  perimeter_se             569 non-null    float64
#  15  area_se                  569 non-null    float64
#  16  smoothness_se            569 non-null    float64
#  17  compactness_se           569 non-null    float64
#  18  concavity_se             569 non-null    float64
#  19  concave points_se        569 non-null    float64
#  20  symmetry_se              569 non-null    float64
#  21  fractal_dimension_se     569 non-null    float64
#  22  radius_worst             569 non-null    float64
#  23  texture_worst            569 non-null    float64
#  24  perimeter_worst          569 non-null    float64
#  25  area_worst               569 non-null    float64
#  26  smoothness_worst         569 non-null    float64
#  27  compactness_worst        569 non-null    float64
#  28  concavity_worst          569 non-null    float64
#  29  concave points_worst     569 non-null    float64
#  30  symmetry_worst           569 non-null    float64
#  31  fractal_dimension_worst  569 non-null    float64
# dtypes: float64(30), int64(1), object(1)
# memory usage: 142.4+ KB

# %%
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# 25%           0.086370          0.064920        0.029560             0.020310
# 50%           0.095870          0.092630        0.061540             0.033500
# 75%           0.105300          0.130400        0.130700             0.074000
# max           0.163400          0.345400        0.426800             0.201200
#
#        symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# count     569.000000  ...    569.000000     569.000000       569.000000
# mean        0.181162  ...     16.269190      25.677223       107.261213
# std         0.027414  ...      4.833242       6.146258        33.602542
# min         0.106000  ...      7.930000      12.020000        50.410000
# 25%         0.161900  ...     13.010000      21.080000        84.110000
# 50%         0.179200  ...     14.970000      25.410000        97.660000
# 75%         0.195700  ...     18.790000      29.720000       125.400000
# max         0.304000  ...     36.040000      49.540000       251.200000
#
#         area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# count   569.000000        569.000000         569.000000       569.000000
# mean    880.583128          0.132369           0.254265         0.272188
# std     569.356993          0.022832           0.157336         0.208624
# min     185.200000          0.071170           0.027290         0.000000
# 25%     515.300000          0.116600           0.147200         0.114500
# 50%     686.500000          0.131300           0.211900         0.226700
# 75%    1084.000000          0.146000           0.339100         0.382900
# max    4254.000000          0.222600           1.058000         1.252000
#
#        concave points_worst  symmetry_worst  fractal_dimension_worst
# count            569.000000      569.000000               569.000000
# mean               0.114606        0.290076                 0.083946
# std                0.065732        0.061867                 0.018061
# min                0.000000        0.156500                 0.055040
# 25%                0.064930        0.250400                 0.071460
# 50%                0.099930        0.282200                 0.080040
# 75%                0.161400        0.317900                 0.092080
# max                0.291000        0.663800                 0.207500
#
# [8 rows x 31 columns]

# %%
# Summarise class details
sns.countplot(x=df['diagnosis'])

# %% [markdown]
# ## Extracting labels and features

# %%
# extract labels
y = df['diagnosis']
y = pd.Series(y)
print(y.value_counts())
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
# remove unnecessary columns
X = df.drop(['id', 'diagnosis'], axis=1)
print(X.info())
X.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   radius_mean              569 non-null    float64
#  1   texture_mean             569 non-null    float64
#  2   perimeter_mean           569 non-null    float64
#  3   area_mean                569 non-null    float64
#  4   smoothness_mean          569 non-null    float64
#  5   compactness_mean         569 non-null    float64
#  6   concavity_mean           569 non-null    float64
#  7   concave points_mean      569 non-null    float64
#  8   symmetry_mean            569 non-null    float64
#  9   fractal_dimension_mean   569 non-null    float64
#  10  radius_se                569 non-null    float64
#  11  texture_se               569 non-null    float64
#  12  perimeter_se             569 non-null    float64
#  13  area_se                  569 non-null    float64
#  14  smoothness_se            569 non-null    float64
#  15  compactness_se           569 non-null    float64
#  16  concavity_se             569 non-null    float64
#  17  concave points_se        569 non-null    float64
#  18  symmetry_se              569 non-null    float64
#  19  fractal_dimension_se     569 non-null    float64
#  20  radius_worst             569 non-null    float64
#  21  texture_worst            569 non-null    float64
#  22  perimeter_worst          569 non-null    float64
#  23  area_worst               569 non-null    float64
#  24  smoothness_worst         569 non-null    float64
#  25  compactness_worst        569 non-null    float64
#  26  concavity_worst          569 non-null    float64
#  27  concave points_worst     569 non-null    float64
#  28  symmetry_worst           569 non-null    float64
#  29  fractal_dimension_worst  569 non-null    float64
# dtypes: float64(30)
# memory usage: 133.5 KB
# None
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0                 0.07871  ...         25.38          17.33           184.60
# 1                 0.05667  ...         24.99          23.41           158.80
# 2                 0.05999  ...         23.57          25.53           152.50
# 3                 0.09744  ...         14.91          26.50            98.87
# 4                 0.05883  ...         22.54          16.67           152.20
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %% [markdown]
# Since we have characters ('M' and 'B') as labels, they need to be converted into numeric values. <br>
# This can be easily done using a LabelEncoder

# %%
# create LabelEncoder for labels 
le = LabelEncoder()
le.fit(y)
# Out:
# LabelEncoder()

# %%
# Convert labels into numeric values
y = le.transform(y)

y = pd.Series(y)
print(y.value_counts())
# Out:
# 0    357
# 1    212
# dtype: int64

# %% [markdown]
# ## M1
#
# As the initial model, let's think about a simple model using 8 features and 2 hidden layers.
#
# ![](https://github.com/HHansi/Applied-AI-Course/blob/main/DL/images/Simple_neural_network.png?raw=true)

# %% [markdown]
# Let's select the first 8 features for this model.

# %%
X1 = X.iloc[:, 0:8]
X1.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean
# 0           0.27760          0.3001              0.14710
# 1           0.07864          0.0869              0.07017
# 2           0.15990          0.1974              0.12790
# 3           0.28390          0.2414              0.10520
# 4           0.13280          0.1980              0.10430

# %% [markdown]
# ### Split Data

# %%
# split data to train and validation sets
X_train1, X_val1, y_train1, y_val1 = train_test_split(X1, y, test_size=0.3, random_state=100)
print(f'training data set size: {len(X_train1)}')
print(f'validation data set size: {len(X_val1)}')
# Out:
# training data set size: 398
# validation data set size: 171

# %% [markdown]
# ### Build Model

# %% [markdown]
# A [Sequential](https://keras.io/guides/sequential_model/) model is appropriate for a plain stack of layers.<br>
# The layers of network can be defined using [Dense](https://keras.io/api/layers/core_layers/dense/) layers (regular densely-connected NN layers)
#
# More details about model training using Keras can be found in the documentation: [Model training APIs](https://keras.io/api/models/model_training_apis/#compile-method).

# %%
# define the keras model
model1 = keras.Sequential()
model1.add(layers.Dense(12, input_dim=8, activation='relu'))
model1.add(layers.Dense(8, activation='relu'))
model1.add(layers.Dense(1, activation='sigmoid'))

model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 12)                108
#
#  dense_1 (Dense)             (None, 8)                 104
#
#  dense_2 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 221
# Trainable params: 221
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compile the keras model
model1.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# train model
model1.fit(X_train1, y_train1, batch_size=50, epochs=60, validation_data=(X_val1, y_val1))
# Out:
# Epoch 1/60
# 8/8 [==============================] - 3s 30ms/step - loss: 56.0839 - accuracy: 0.6407 - val_loss: 55.6247 - val_accuracy: 0.5965
# Epoch 2/60
# 8/8 [==============================] - 0s 6ms/step - loss: 44.7801 - accuracy: 0.6407 - val_loss: 43.1939 - val_accuracy: 0.5965
# Epoch 3/60
# 8/8 [==============================] - 0s 6ms/step - loss: 33.6274 - accuracy: 0.6407 - val_loss: 31.0940 - val_accuracy: 0.5965
# Epoch 4/60
# 8/8 [==============================] - 0s 8ms/step - loss: 23.0594 - accuracy: 0.6407 - val_loss: 18.9415 - val_accuracy: 0.5965
# Epoch 5/60
# 8/8 [==============================] - 0s 6ms/step - loss: 12.2632 - accuracy: 0.5980 - val_loss: 7.2959 - val_accuracy: 0.4737
# Epoch 6/60
# 8/8 [==============================] - 0s 6ms/step - loss: 4.9146 - accuracy: 0.2889 - val_loss: 5.2244 - val_accuracy: 0.3567
# Epoch 7/60
# 8/8 [==============================] - 0s 7ms/step - loss: 5.6495 - accuracy: 0.3367 - val_loss: 4.9339 - val_accuracy: 0.3918
# Epoch 8/60
# 8/8 [==============================] - 0s 6ms/step - loss: 4.2671 - accuracy: 0.2487 - val_loss: 4.0585 - val_accuracy: 0.1696
# Epoch 9/60
# 8/8 [==============================] - 0s 8ms/step - loss: 3.9415 - accuracy: 0.1734 - val_loss: 4.2433 - val_accuracy: 0.2105
# Epoch 10/60
# 8/8 [==============================] - 0s 8ms/step - loss: 3.5873 - accuracy: 0.2010 - val_loss: 2.9688 - val_accuracy: 0.2281
# Epoch 11/60
# 8/8 [==============================] - 0s 6ms/step - loss: 1.7264 - accuracy: 0.3894 - val_loss: 0.8300 - val_accuracy: 0.5965
# Epoch 12/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6236 - accuracy: 0.7362 - val_loss: 0.6036 - val_accuracy: 0.8012
# Epoch 13/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4289 - accuracy: 0.8392 - val_loss: 0.4489 - val_accuracy: 0.8246
# Epoch 14/60
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4392 - accuracy: 0.8291 - val_loss: 0.4671 - val_accuracy: 0.8363
# Epoch 15/60
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4065 - accuracy: 0.8266 - val_loss: 0.4434 - val_accuracy: 0.8421
# Epoch 16/60
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3986 - accuracy: 0.8392 - val_loss: 0.4504 - val_accuracy: 0.8363
# Epoch 17/60
# 8/8 [==============================] - 0s 8ms/step - loss: 0.3960 - accuracy: 0.8467 - val_loss: 0.4389 - val_accuracy: 0.8363
# Epoch 18/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4125 - accuracy: 0.8266 - val_loss: 0.4459 - val_accuracy: 0.8363
# Epoch 19/60
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4063 - accuracy: 0.8241 - val_loss: 0.4467 - val_accuracy: 0.8363
# Epoch 20/60
# 8/8 [==============================] - 0s 8ms/step - loss: 0.3973 - accuracy: 0.8467 - val_loss: 0.4322 - val_accuracy: 0.8363
# Epoch 21/60
# 8/8 [==============================] - 0s 8ms/step - loss: 0.3947 - accuracy: 0.8392 - val_loss: 0.4318 - val_accuracy: 0.8421
# Epoch 22/60
# 8/8 [==============================] - 0s 8ms/step - loss: 0.3915 - accuracy: 0.8241 - val_loss: 0.4475 - val_accuracy: 0.8363
# Epoch 23/60
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4010 - accuracy: 0.8518 - val_loss: 0.4244 - val_accuracy: 0.8421
# Epoch 24/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3951 - accuracy: 0.8166 - val_loss: 0.4425 - val_accuracy: 0.8363
# Epoch 25/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3946 - accuracy: 0.8367 - val_loss: 0.4249 - val_accuracy: 0.8421
# Epoch 26/60
# 8/8 [==============================] - 0s 8ms/step - loss: 0.3940 - accuracy: 0.8568 - val_loss: 0.4189 - val_accuracy: 0.8480
# Epoch 27/60
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3860 - accuracy: 0.8367 - val_loss: 0.4271 - val_accuracy: 0.8421
# Epoch 28/60
# 8/8 [==============================] - 0s 9ms/step - loss: 0.3890 - accuracy: 0.8518 - val_loss: 0.4186 - val_accuracy: 0.8363
# Epoch 29/60
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3902 - accuracy: 0.8241 - val_loss: 0.4203 - val_accuracy: 0.8421
# Epoch 30/60
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3715 - accuracy: 0.8568 - val_loss: 0.4176 - val_accuracy: 0.8421
# Epoch 31/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3712 - accuracy: 0.8518 - val_loss: 0.4191 - val_accuracy: 0.8363
# Epoch 32/60
# 8/8 [==============================] - 0s 8ms/step - loss: 0.3714 - accuracy: 0.8467 - val_loss: 0.4108 - val_accuracy: 0.8421
# Epoch 33/60
# 8/8 [==============================] - 0s 8ms/step - loss: 0.3742 - accuracy: 0.8618 - val_loss: 0.4039 - val_accuracy: 0.8480
# Epoch 34/60
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3748 - accuracy: 0.8417 - val_loss: 0.4166 - val_accuracy: 0.8363
# Epoch 35/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3706 - accuracy: 0.8593 - val_loss: 0.3995 - val_accuracy: 0.8480
# Epoch 36/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3740 - accuracy: 0.8392 - val_loss: 0.4507 - val_accuracy: 0.8246
# Epoch 37/60
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4066 - accuracy: 0.8417 - val_loss: 0.4072 - val_accuracy: 0.8304
# Epoch 38/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3624 - accuracy: 0.8543 - val_loss: 0.4430 - val_accuracy: 0.8246
# Epoch 39/60
# 8/8 [==============================] - 0s 8ms/step - loss: 0.3576 - accuracy: 0.8643 - val_loss: 0.4029 - val_accuracy: 0.8304
# Epoch 40/60
# 8/8 [==============================] - 0s 8ms/step - loss: 0.3912 - accuracy: 0.8467 - val_loss: 0.4187 - val_accuracy: 0.8363
# Epoch 41/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3707 - accuracy: 0.8518 - val_loss: 0.3899 - val_accuracy: 0.8480
# Epoch 42/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3616 - accuracy: 0.8568 - val_loss: 0.3878 - val_accuracy: 0.8480
# Epoch 43/60
# 8/8 [==============================] - 0s 8ms/step - loss: 0.3593 - accuracy: 0.8317 - val_loss: 0.4097 - val_accuracy: 0.8363
# Epoch 44/60
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3661 - accuracy: 0.8668 - val_loss: 0.3955 - val_accuracy: 0.8246
# Epoch 45/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3756 - accuracy: 0.8291 - val_loss: 0.4638 - val_accuracy: 0.8129
# Epoch 46/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3620 - accuracy: 0.8518 - val_loss: 0.3908 - val_accuracy: 0.8304
# Epoch 47/60
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3545 - accuracy: 0.8593 - val_loss: 0.4016 - val_accuracy: 0.8363
# Epoch 48/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3439 - accuracy: 0.8492 - val_loss: 0.3807 - val_accuracy: 0.8363
# Epoch 49/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3601 - accuracy: 0.8467 - val_loss: 0.3810 - val_accuracy: 0.8480
# Epoch 50/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3497 - accuracy: 0.8392 - val_loss: 0.3877 - val_accuracy: 0.8421
# Epoch 51/60
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3621 - accuracy: 0.8593 - val_loss: 0.3770 - val_accuracy: 0.8363
# Epoch 52/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3509 - accuracy: 0.8593 - val_loss: 0.3865 - val_accuracy: 0.8363
# Epoch 53/60
# 8/8 [==============================] - 0s 8ms/step - loss: 0.3454 - accuracy: 0.8492 - val_loss: 0.3798 - val_accuracy: 0.8480
# Epoch 54/60
# 8/8 [==============================] - 0s 8ms/step - loss: 0.3411 - accuracy: 0.8643 - val_loss: 0.3729 - val_accuracy: 0.8363
# Epoch 55/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3447 - accuracy: 0.8518 - val_loss: 0.3788 - val_accuracy: 0.8421
# Epoch 56/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3345 - accuracy: 0.8543 - val_loss: 0.3666 - val_accuracy: 0.8596
# Epoch 57/60
# 8/8 [==============================] - 0s 8ms/step - loss: 0.3480 - accuracy: 0.8518 - val_loss: 0.3996 - val_accuracy: 0.8246
# Epoch 58/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3427 - accuracy: 0.8618 - val_loss: 0.3627 - val_accuracy: 0.8596
# Epoch 59/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3675 - accuracy: 0.8518 - val_loss: 0.3880 - val_accuracy: 0.8187
# Epoch 60/60
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4111 - accuracy: 0.8216 - val_loss: 0.4913 - val_accuracy: 0.8070

# %% [markdown]
# ### Validate Model
#
# Validation accuracy is measured in the previous step too. But let's see how to do it separately.

# %%
# get model predictions
y_pred1 = model1.predict(X_val1)
print(y_pred1[:10])
# Out:
# 6/6 [==============================] - 0s 3ms/step
# [[0.66414666]
#  [0.19253758]
#  [0.9955611 ]
#  [0.02139875]
#  [0.01898685]
#  [0.02253969]
#  [0.8900353 ]
#  [0.992128  ]
#  [0.05522048]
#  [0.01560934]]

# %%
# convert to categorical predictions
y_pred_categorical1 = [1 if pred > 0.5 else 0 for pred in y_pred1]
print(y_pred_categorical1[:10])
# Out:
# [1, 0, 1, 0, 0, 0, 1, 1, 0, 0]

# %%
# measure accuracy
accuracy = metrics.accuracy_score(y_val1, y_pred_categorical1)
print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.8070175438596491

# %% [markdown]
# ### Test Predictions

# %%
df_test = pd.read_csv('https://raw.githubusercontent.com/HHansi/Applied-AI-Course/2022/DL/data/cancer_data_test.csv')

# summarise the details
print(f'Number of entries: {len(df_test)}')

X_test = df_test.drop(['id'], axis=1)
print(X_test.info())
# Out:
# Number of entries: 6
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   radius_mean              6 non-null      float64
#  1   texture_mean             6 non-null      float64
#  2   perimeter_mean           6 non-null      float64
#  3   area_mean                6 non-null      float64
#  4   smoothness_mean          6 non-null      float64
#  5   compactness_mean         6 non-null      float64
#  6   concavity_mean           6 non-null      float64
#  7   concave points_mean      6 non-null      float64
#  8   symmetry_mean            6 non-null      float64
#  9   fractal_dimension_mean   6 non-null      float64
#  10  radius_se                6 non-null      float64
#  11  texture_se               6 non-null      float64
#  12  perimeter_se             6 non-null      float64
#  13  area_se                  6 non-null      float64
#  14  smoothness_se            6 non-null      float64
#  15  compactness_se           6 non-null      float64
#  16  concavity_se             6 non-null      float64
#  17  concave points_se        6 non-null      float64
#  18  symmetry_se              6 non-null      float64
#  19  fractal_dimension_se     6 non-null      float64
#  20  radius_worst             6 non-null      float64
#  21  texture_worst            6 non-null      float64
#  22  perimeter_worst          6 non-null      float64
#  23  area_worst               6 non-null      float64
#  24  smoothness_worst         6 non-null      float64
#  25  compactness_worst        6 non-null      float64
#  26  concavity_worst          6 non-null      float64
#  27  concave points_worst     6 non-null      float64
#  28  symmetry_worst           6 non-null      float64
#  29  fractal_dimension_worst  6 non-null      float64
# dtypes: float64(30)
# memory usage: 1.5 KB
# None

# %%
X_test1 = X_test.iloc[:, 0:8]
X_test1.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0       13.000         21.82           87.50      519.8          0.12730
# 1        8.196         16.84           51.71      201.9          0.08600
# 2       13.170         18.66           85.98      534.6          0.11580
# 3        9.173         13.86           59.20      260.9          0.07721
# 4       22.270         19.67          152.80     1509.0          0.13260
#
#    compactness_mean  concavity_mean  concave points_mean
# 0           0.19320         0.18590             0.093530
# 1           0.05943         0.01588             0.005917
# 2           0.12310         0.12260             0.073400
# 3           0.08751         0.05988             0.021800
# 4           0.27680         0.42640             0.182300

# %%
test_pred = model1.predict(X_test1)
print(test_pred)

test_pred_categorical = [1 if pred > 0.5 else 0 for pred in test_pred]
print(test_pred_categorical)

test_pred_encoded = le.inverse_transform(test_pred_categorical)
print(test_pred_encoded)
# Out:
# 1/1 [==============================] - 0s 18ms/step
# [[0.0219425 ]
#  [0.00788042]
#  [0.0450492 ]
#  [0.01178375]
#  [0.9993192 ]
#  [0.00455116]]
# [0, 0, 0, 0, 1, 0]
# ['B' 'B' 'B' 'B' 'M' 'B']

# %% [markdown]
# ## Clear Keras Session
#
# Keras manages a global state, which it uses to implement the Functional model-building API and to uniquify autogenerated layer names. If you are creating many models in one session, this global state will consume an increasing amount of memory over time.
#
# Calling [clear_session()](https://www.tensorflow.org/api_docs/python/tf/keras/backend/clear_session) releases the global state: this helps avoid clutter from old models and layers, especially when memory is limited.
#
# Once the session is cleared, you need to make sure to set back any important states you require (like random state).

# %%
# clear session
keras.backend.clear_session()

# set random seed
keras.utils.set_random_seed(seed) # set all random seeds for the program (Python, NumPy, and TensorFlow)

# %% [markdown]
# ## M2
#
# Let's build a more complex model with 30 features and more neurons.

# %%
X.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0                 0.07871  ...         25.38          17.33           184.60
# 1                 0.05667  ...         24.99          23.41           158.80
# 2                 0.05999  ...         23.57          25.53           152.50
# 3                 0.09744  ...         14.91          26.50            98.87
# 4                 0.05883  ...         22.54          16.67           152.20
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %% [markdown]
# ### Split Data

# %%
# split data to train and validation sets
X_train2, X_val2, y_train2, y_val2 = train_test_split(X, y, test_size=0.3, random_state=100)
print(f'training data set size: {len(X_train2)}')
print(f'validation data set size: {len(X_val2)}')
# Out:
# training data set size: 398
# validation data set size: 171

# %% [markdown]
# ### Build Model

# %%
# define the keras model
model2 = keras.Sequential()
model2.add(layers.Dense(64, input_dim=30, activation='relu'))
model2.add(layers.Dense(32, activation='relu'))
model2.add(layers.Dense(1, activation='sigmoid'))

model2.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                1984
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 4,097
# Trainable params: 4,097
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compile the keras model
model2.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# train model
model2.fit(X_train2, y_train2, batch_size=50, epochs=60, validation_data=(X_val2, y_val2))
# Out:
# Epoch 1/60
# 8/8 [==============================] - 1s 25ms/step - loss: 6.8387 - accuracy: 0.5905 - val_loss: 0.9845 - val_accuracy: 0.6433
# Epoch 2/60
# 8/8 [==============================] - 0s 7ms/step - loss: 1.5531 - accuracy: 0.6533 - val_loss: 1.5114 - val_accuracy: 0.8363
# Epoch 3/60
# 8/8 [==============================] - 0s 6ms/step - loss: 1.0584 - accuracy: 0.8442 - val_loss: 0.9957 - val_accuracy: 0.6959
# Epoch 4/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.8595 - accuracy: 0.7764 - val_loss: 0.6821 - val_accuracy: 0.8538
# Epoch 5/60
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4997 - accuracy: 0.8593 - val_loss: 0.2676 - val_accuracy: 0.9181
# Epoch 6/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3010 - accuracy: 0.8794 - val_loss: 0.2719 - val_accuracy: 0.9064
# Epoch 7/60
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2921 - accuracy: 0.8844 - val_loss: 0.2536 - val_accuracy: 0.8947
# Epoch 8/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2870 - accuracy: 0.8920 - val_loss: 0.2419 - val_accuracy: 0.9006
# Epoch 9/60
# 8/8 [==============================] - 0s 8ms/step - loss: 0.2910 - accuracy: 0.8920 - val_loss: 0.2130 - val_accuracy: 0.9240
# Epoch 10/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2514 - accuracy: 0.9095 - val_loss: 0.2220 - val_accuracy: 0.9181
# Epoch 11/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2909 - accuracy: 0.8844 - val_loss: 0.2106 - val_accuracy: 0.9240
# Epoch 12/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3157 - accuracy: 0.8920 - val_loss: 0.1991 - val_accuracy: 0.9240
# Epoch 13/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2840 - accuracy: 0.8970 - val_loss: 0.1981 - val_accuracy: 0.9240
# Epoch 14/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2876 - accuracy: 0.8894 - val_loss: 0.2160 - val_accuracy: 0.9240
# Epoch 15/60
# 8/8 [==============================] - 0s 8ms/step - loss: 0.3338 - accuracy: 0.8894 - val_loss: 0.2432 - val_accuracy: 0.9181
# Epoch 16/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2508 - accuracy: 0.9171 - val_loss: 0.3199 - val_accuracy: 0.8947
# Epoch 17/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2329 - accuracy: 0.9095 - val_loss: 0.1942 - val_accuracy: 0.9240
# Epoch 18/60
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2482 - accuracy: 0.9070 - val_loss: 0.3251 - val_accuracy: 0.8772
# Epoch 19/60
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2950 - accuracy: 0.9221 - val_loss: 0.1949 - val_accuracy: 0.9415
# Epoch 20/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2417 - accuracy: 0.9171 - val_loss: 0.1826 - val_accuracy: 0.9415
# Epoch 21/60
# 8/8 [==============================] - 0s 8ms/step - loss: 0.2735 - accuracy: 0.9171 - val_loss: 0.1853 - val_accuracy: 0.9357
# Epoch 22/60
# 8/8 [==============================] - 0s 8ms/step - loss: 0.2527 - accuracy: 0.9095 - val_loss: 0.2390 - val_accuracy: 0.9181
# Epoch 23/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2648 - accuracy: 0.9121 - val_loss: 0.2352 - val_accuracy: 0.9123
# Epoch 24/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2339 - accuracy: 0.9246 - val_loss: 0.1869 - val_accuracy: 0.9357
# Epoch 25/60
# 8/8 [==============================] - 0s 8ms/step - loss: 0.2211 - accuracy: 0.9196 - val_loss: 0.2193 - val_accuracy: 0.9181
# Epoch 26/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2264 - accuracy: 0.9171 - val_loss: 0.1756 - val_accuracy: 0.9298
# Epoch 27/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2518 - accuracy: 0.9070 - val_loss: 0.1690 - val_accuracy: 0.9298
# Epoch 28/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2516 - accuracy: 0.9171 - val_loss: 0.2106 - val_accuracy: 0.9298
# Epoch 29/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3506 - accuracy: 0.8719 - val_loss: 0.3616 - val_accuracy: 0.8655
# Epoch 30/60
# 8/8 [==============================] - 0s 8ms/step - loss: 0.2920 - accuracy: 0.9221 - val_loss: 0.2707 - val_accuracy: 0.9064
# Epoch 31/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2792 - accuracy: 0.9095 - val_loss: 0.1923 - val_accuracy: 0.9240
# Epoch 32/60
# 8/8 [==============================] - 0s 8ms/step - loss: 0.2346 - accuracy: 0.9171 - val_loss: 0.2171 - val_accuracy: 0.9181
# Epoch 33/60
# 8/8 [==============================] - 0s 8ms/step - loss: 0.2270 - accuracy: 0.9121 - val_loss: 0.1730 - val_accuracy: 0.9415
# Epoch 34/60
# 8/8 [==============================] - 0s 8ms/step - loss: 0.2228 - accuracy: 0.9221 - val_loss: 0.1826 - val_accuracy: 0.9298
# Epoch 35/60
# 8/8 [==============================] - 0s 8ms/step - loss: 0.2455 - accuracy: 0.9221 - val_loss: 0.1940 - val_accuracy: 0.9240
# Epoch 36/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2800 - accuracy: 0.8995 - val_loss: 0.1875 - val_accuracy: 0.9357
# Epoch 37/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2204 - accuracy: 0.9171 - val_loss: 0.1711 - val_accuracy: 0.9298
# Epoch 38/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1912 - accuracy: 0.9221 - val_loss: 0.2084 - val_accuracy: 0.9181
# Epoch 39/60
# 8/8 [==============================] - 0s 8ms/step - loss: 0.2271 - accuracy: 0.9296 - val_loss: 0.2196 - val_accuracy: 0.9181
# Epoch 40/60
# 8/8 [==============================] - 0s 8ms/step - loss: 0.1831 - accuracy: 0.9322 - val_loss: 0.1815 - val_accuracy: 0.9298
# Epoch 41/60
# 8/8 [==============================] - 0s 7ms/step - loss: 0.1958 - accuracy: 0.9196 - val_loss: 0.1620 - val_accuracy: 0.9415
# Epoch 42/60
# 8/8 [==============================] - 0s 7ms/step - loss: 0.1827 - accuracy: 0.9372 - val_loss: 0.1896 - val_accuracy: 0.9240
# Epoch 43/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1872 - accuracy: 0.9296 - val_loss: 0.1548 - val_accuracy: 0.9415
# Epoch 44/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1770 - accuracy: 0.9271 - val_loss: 0.1607 - val_accuracy: 0.9415
# Epoch 45/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1858 - accuracy: 0.9322 - val_loss: 0.1664 - val_accuracy: 0.9357
# Epoch 46/60
# 8/8 [==============================] - 0s 8ms/step - loss: 0.2258 - accuracy: 0.9146 - val_loss: 0.1755 - val_accuracy: 0.9415
# Epoch 47/60
# 8/8 [==============================] - 0s 8ms/step - loss: 0.2167 - accuracy: 0.9196 - val_loss: 0.1647 - val_accuracy: 0.9415
# Epoch 48/60
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2028 - accuracy: 0.9221 - val_loss: 0.2376 - val_accuracy: 0.9181
# Epoch 49/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2425 - accuracy: 0.9121 - val_loss: 0.1591 - val_accuracy: 0.9415
# Epoch 50/60
# 8/8 [==============================] - 0s 8ms/step - loss: 0.2062 - accuracy: 0.9221 - val_loss: 0.2621 - val_accuracy: 0.9240
# Epoch 51/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2018 - accuracy: 0.9372 - val_loss: 0.1635 - val_accuracy: 0.9298
# Epoch 52/60
# 8/8 [==============================] - 0s 8ms/step - loss: 0.1805 - accuracy: 0.9372 - val_loss: 0.1630 - val_accuracy: 0.9240
# Epoch 53/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1992 - accuracy: 0.9322 - val_loss: 0.1497 - val_accuracy: 0.9415
# Epoch 54/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2020 - accuracy: 0.9221 - val_loss: 0.2602 - val_accuracy: 0.9064
# Epoch 55/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2568 - accuracy: 0.9070 - val_loss: 0.1778 - val_accuracy: 0.9357
# Epoch 56/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2021 - accuracy: 0.9271 - val_loss: 0.1893 - val_accuracy: 0.9240
# Epoch 57/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1653 - accuracy: 0.9397 - val_loss: 0.3954 - val_accuracy: 0.8713
# Epoch 58/60
# 8/8 [==============================] - 0s 8ms/step - loss: 0.2733 - accuracy: 0.8970 - val_loss: 0.1682 - val_accuracy: 0.9415
# Epoch 59/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2705 - accuracy: 0.9020 - val_loss: 0.1495 - val_accuracy: 0.9357
# Epoch 60/60
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3065 - accuracy: 0.8945 - val_loss: 0.1790 - val_accuracy: 0.9298

# %% [markdown]
# ### Test Predictions

# %%
df_test = pd.read_csv('https://raw.githubusercontent.com/HHansi/Applied-AI-Course/2022/DL/data/cancer_data_test.csv')

# summarise the details
print(f'Number of entries: {len(df_test)}')

X_test = df_test.drop(['id'], axis=1)
print(X_test.info())
# Out:
# Number of entries: 6
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   radius_mean              6 non-null      float64
#  1   texture_mean             6 non-null      float64
#  2   perimeter_mean           6 non-null      float64
#  3   area_mean                6 non-null      float64
#  4   smoothness_mean          6 non-null      float64
#  5   compactness_mean         6 non-null      float64
#  6   concavity_mean           6 non-null      float64
#  7   concave points_mean      6 non-null      float64
#  8   symmetry_mean            6 non-null      float64
#  9   fractal_dimension_mean   6 non-null      float64
#  10  radius_se                6 non-null      float64
#  11  texture_se               6 non-null      float64
#  12  perimeter_se             6 non-null      float64
#  13  area_se                  6 non-null      float64
#  14  smoothness_se            6 non-null      float64
#  15  compactness_se           6 non-null      float64
#  16  concavity_se             6 non-null      float64
#  17  concave points_se        6 non-null      float64
#  18  symmetry_se              6 non-null      float64
#  19  fractal_dimension_se     6 non-null      float64
#  20  radius_worst             6 non-null      float64
#  21  texture_worst            6 non-null      float64
#  22  perimeter_worst          6 non-null      float64
#  23  area_worst               6 non-null      float64
#  24  smoothness_worst         6 non-null      float64
#  25  compactness_worst        6 non-null      float64
#  26  concavity_worst          6 non-null      float64
#  27  concave points_worst     6 non-null      float64
#  28  symmetry_worst           6 non-null      float64
#  29  fractal_dimension_worst  6 non-null      float64
# dtypes: float64(30)
# memory usage: 1.5 KB
# None

# %%
test_pred = model2.predict(X_test)
print(test_pred)

test_pred_categorical = [1 if pred > 0.5 else 0 for pred in test_pred]
print(test_pred_categorical)

test_pred_encoded = le.inverse_transform(test_pred_categorical)
print(test_pred_encoded)
# Out:
# 1/1 [==============================] - 0s 48ms/step
# [[9.81645703e-01]
#  [9.75723611e-04]
#  [9.86140370e-01]
#  [3.36686498e-03]
#  [1.00000000e+00]
#  [1.01172775e-01]]
# [1, 0, 1, 0, 1, 0]
# ['M' 'B' 'M' 'B' 'M' 'B']

# %% [markdown]
# **Exercise**
#
# 1. What is the best validation loss and validation accuracy of *model2* obtained during the above training process?
# 2. Is the final model obtained as *model2* the best model we can build?

# %% [markdown]
# ## Early Stopping
#
# [Early stopping](https://keras.io/api/callbacks/early_stopping/) stops training when a monitored metric has stopped improving.

# %%
# clear session
keras.backend.clear_session()

# set random seed
keras.utils.set_random_seed(seed) # set all random seeds for the program (Python, NumPy, and TensorFlow)

# %%
callback = keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=3)

# define the keras model
model2_1 = keras.Sequential()
model2_1.add(layers.Dense(64, input_dim=30, activation='relu'))
model2_1.add(layers.Dense(32, activation='relu'))
model2_1.add(layers.Dense(1, activation='sigmoid'))

model2_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                1984
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 4,097
# Trainable params: 4,097
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compile the keras model
model2_1.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# train model with early stopping
model2_1.fit(X_train2, y_train2, batch_size=50, epochs=60, validation_data=(X_val2, y_val2), callbacks=[callback])
# Out:
# Epoch 1/60
# 8/8 [==============================] - 1s 24ms/step - loss: 6.8387 - accuracy: 0.5905 - val_loss: 0.9845 - val_accuracy: 0.6433
# Epoch 2/60
# 8/8 [==============================] - 0s 6ms/step - loss: 1.5531 - accuracy: 0.6533 - val_loss: 1.5114 - val_accuracy: 0.8363
# Epoch 3/60
# 8/8 [==============================] - 0s 9ms/step - loss: 1.0584 - accuracy: 0.8442 - val_loss: 0.9957 - val_accuracy: 0.6959
# Epoch 4/60
# 8/8 [==============================] - 0s 7ms/step - loss: 0.8595 - accuracy: 0.7764 - val_loss: 0.6821 - val_accuracy: 0.8538
# Epoch 5/60
# 8/8 [==============================] - 0s 9ms/step - loss: 0.4997 - accuracy: 0.8593 - val_loss: 0.2676 - val_accuracy: 0.9181
# Epoch 6/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3010 - accuracy: 0.8794 - val_loss: 0.2719 - val_accuracy: 0.9064
# Epoch 7/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2921 - accuracy: 0.8844 - val_loss: 0.2536 - val_accuracy: 0.8947
# Epoch 8/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2870 - accuracy: 0.8920 - val_loss: 0.2419 - val_accuracy: 0.9006

# %% [markdown]
# **Exercise**
#
# 1. What is the validation accuracy of *model2_1* build above? <br>
#   **Hint:** You can check your answer by calculating the validation accuracy separately using the approach discussed under [M1>Validate Model](https://colab.research.google.com/drive/1uRq2uAsuT4O5dn-08o4-kUZds1cXfq0o?authuser=1#scrollTo=MCJxLR9HTpQI).
# 2. Is it the best value achived during the training process?

# %% [markdown]
# ### Early Stopping with More Parameters

# %%
# clear session
keras.backend.clear_session()

# set random seed
keras.utils.set_random_seed(seed) # set all random seeds for the program (Python, NumPy, and TensorFlow)

# %%
callback2 = keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=3, restore_best_weights=True)

# define the keras model
model2_2 = keras.Sequential()
model2_2.add(layers.Dense(64, input_dim=30, activation='relu'))
model2_2.add(layers.Dense(32, activation='relu'))
model2_2.add(layers.Dense(1, activation='sigmoid'))

model2_2.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                1984
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 4,097
# Trainable params: 4,097
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compile the keras model
model2_2.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# train model
model2_2.fit(X_train2, y_train2, batch_size=50, epochs=60, validation_data=(X_val2, y_val2), callbacks=[callback2])
# Out:
# Epoch 1/60
# 8/8 [==============================] - 1s 50ms/step - loss: 6.8387 - accuracy: 0.5905 - val_loss: 0.9845 - val_accuracy: 0.6433
# Epoch 2/60
# 8/8 [==============================] - 0s 7ms/step - loss: 1.5531 - accuracy: 0.6533 - val_loss: 1.5114 - val_accuracy: 0.8363
# Epoch 3/60
# 8/8 [==============================] - 0s 8ms/step - loss: 1.0584 - accuracy: 0.8442 - val_loss: 0.9957 - val_accuracy: 0.6959
# Epoch 4/60
# 8/8 [==============================] - 0s 8ms/step - loss: 0.8595 - accuracy: 0.7764 - val_loss: 0.6821 - val_accuracy: 0.8538
# Epoch 5/60
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4997 - accuracy: 0.8593 - val_loss: 0.2676 - val_accuracy: 0.9181
# Epoch 6/60
# 8/8 [==============================] - 0s 8ms/step - loss: 0.3010 - accuracy: 0.8794 - val_loss: 0.2719 - val_accuracy: 0.9064
# Epoch 7/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2921 - accuracy: 0.8844 - val_loss: 0.2536 - val_accuracy: 0.8947
# Epoch 8/60
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2870 - accuracy: 0.8920 - val_loss: 0.2419 - val_accuracy: 0.9006

# %% [markdown]
# **Exercise**
#
# 1. What is the validation accuracy of *model2_2* build above? <br>
#   **Hint:** You can check your answer by calculating the validation accuracy separately using the approach discussed under [M1>Validate Model](https://colab.research.google.com/drive/1uRq2uAsuT4O5dn-08o4-kUZds1cXfq0o?authuser=1#scrollTo=MCJxLR9HTpQI).
# 2. Is it the best value achived during the training process?

# %% [markdown]
# Discuss the following in small groups:
# 1. Which would be the best model among *model2_1* and *model2_2*?
# 2. What monitor metrics can be used with early stopping, and which would be the best?
# 3. How a value for patience can be selected, and what is its impact?
# 4. What are the advantages and disadvantages of early stopping?
